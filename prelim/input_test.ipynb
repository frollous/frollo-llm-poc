# %% [markdown]
# # OKR Test Set

# %%
import sys
import os
from datetime import datetime
import pytz
import pandas as pd
import json
from copy import deepcopy
import os

# %%
# !ls ../frollo-py-inference-pipeline-enrichment/tests/susan/combined_okr_set_2024_08.csv

# %%
df = pd.read_csv("../frollo-py-inference-pipeline-enrichment/tests/susan/combined_okr_set_2024_08.csv")

# %%
df.head()

# %%
df.provider_name.value_counts()

# %%
df.aggregator.value_counts()

# %%
df.base_category_key.value_counts()

# %%
df['OKR labels'].value_counts()

# %% [markdown]
# ### Regression Run output data

# %%
# !ls ../release_testing/nov27/testset_v2_enrich_circleci_shared.csv

# %%
df_out_nov27 = pd.read_csv("../release_testing/nov27/testset_v2_enrich_circleci_shared.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df_out_nov27.head()

# %%
df_out_nov27[df_out_nov27.has_merch_ideasv2==0]['OKR labels'].value_counts()

# %% [markdown]
# ## Test accuracy per provider

# %%
df.columns

# %%
df
